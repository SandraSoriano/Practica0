# %% [markdown]
# # Ejemplo de CNN 2D en la base de datos cifar100

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# Installa TensorFlow
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# 2.9.2

# %%
# descargamos los datos cifar100 y los partimos en train y test
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step

# %%
# Tamaño de los datos (#datos,#lado,#alto,#canales)
print(X_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
import matplotlib.pyplot as plt

# enseñamos la primera imagen del dataset
plt.imshow(X_train[0],cmap="gray")

# %%
# one-hot encoding en las 'y'
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# Modelo

# %%
# Hacemos un modelo con varias capas

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, BatchNormalization, Dropout
from tensorflow.keras import regularizers

#crear modelo
model = Sequential()

#Vamos añadiendo capas
model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(32,32,3),
                activity_regularizer=regularizers.l1(0.2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Conv2D(32, kernel_size=3, activation='relu',
                activity_regularizer=regularizers.l1(0.2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Conv2D(16, kernel_size=3, activation='relu',
                activity_regularizer=regularizers.l1(0.2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(100, activation='softmax'))

# %%
# Compilamos el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Este es el modelo
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  batch_normalization (BatchN  (None, 30, 30, 64)       256
#  ormalization)
#
#  dropout (Dropout)           (None, 30, 30, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        18464
#
#  batch_normalization_1 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 28, 28, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 16)        4624
#
#  batch_normalization_2 (Batc  (None, 26, 26, 16)       64
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 26, 26, 16)        0
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 100)               1081700
#
# =================================================================
# Total params: 1,107,028
# Trainable params: 1,106,804
# Non-trainable params: 224
# _________________________________________________________________

# %%
# Vamos a usar el callback de earlystopping
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=12, min_delta=0.01)

# %%
# Entrenamos
hist = model.fit(X_train, y_train, validation_split=0.3, epochs=50, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 1094/1094 [==============================] - 19s 10ms/step - loss: 1201.9022 - accuracy: 0.0101 - val_loss: 13.0112 - val_accuracy: 0.0084
# Epoch 2/50
# 1094/1094 [==============================] - 10s 9ms/step - loss: 8.8169 - accuracy: 0.0107 - val_loss: 6.9191 - val_accuracy: 0.0087
# Epoch 3/50
# 1094/1094 [==============================] - 10s 9ms/step - loss: 5.9452 - accuracy: 0.0101 - val_loss: 5.5058 - val_accuracy: 0.0091
# Epoch 4/50
# 1094/1094 [==============================] - 10s 9ms/step - loss: 5.1471 - accuracy: 0.0107 - val_loss: 5.0086 - val_accuracy: 0.0089
# Epoch 5/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.8479 - accuracy: 0.0098 - val_loss: 4.8105 - val_accuracy: 0.0084
# Epoch 6/50
# 1094/1094 [==============================] - 10s 9ms/step - loss: 4.7250 - accuracy: 0.0104 - val_loss: 4.7115 - val_accuracy: 0.0093
# Epoch 7/50
# 1094/1094 [==============================] - 13s 12ms/step - loss: 4.6691 - accuracy: 0.0091 - val_loss: 4.6654 - val_accuracy: 0.0091
# Epoch 8/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6420 - accuracy: 0.0085 - val_loss: 4.6439 - val_accuracy: 0.0095
# Epoch 9/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6292 - accuracy: 0.0095 - val_loss: 4.6307 - val_accuracy: 0.0094
# Epoch 10/50
# 1094/1094 [==============================] - 10s 9ms/step - loss: 4.6232 - accuracy: 0.0094 - val_loss: 4.6259 - val_accuracy: 0.0081
# Epoch 11/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6189 - accuracy: 0.0094 - val_loss: 4.6223 - val_accuracy: 0.0095
# Epoch 12/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6167 - accuracy: 0.0094 - val_loss: 4.6200 - val_accuracy: 0.0096
# Epoch 13/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6163 - accuracy: 0.0102 - val_loss: 4.6315 - val_accuracy: 0.0101
# Epoch 14/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6166 - accuracy: 0.0106 - val_loss: 4.6133 - val_accuracy: 0.0084
# Epoch 15/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6149 - accuracy: 0.0103 - val_loss: 4.6224 - val_accuracy: 0.0093
# Epoch 16/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6142 - accuracy: 0.0097 - val_loss: 4.6196 - val_accuracy: 0.0091
# Epoch 17/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6152 - accuracy: 0.0099 - val_loss: 4.6193 - val_accuracy: 0.0094
# Epoch 18/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6144 - accuracy: 0.0096 - val_loss: 4.6199 - val_accuracy: 0.0116
# Epoch 19/50
# 1094/1094 [==============================] - 10s 9ms/step - loss: 4.6155 - accuracy: 0.0097 - val_loss: 4.6102 - val_accuracy: 0.0102
# Epoch 20/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6145 - accuracy: 0.0097 - val_loss: 4.6253 - val_accuracy: 0.0102
# Epoch 21/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6156 - accuracy: 0.0101 - val_loss: 4.6128 - val_accuracy: 0.0086
# Epoch 22/50
# 1094/1094 [==============================] - 8s 8ms/step - loss: 4.6139 - accuracy: 0.0109 - val_loss: 4.6195 - val_accuracy: 0.0091
# Epoch 23/50
# 1094/1094 [==============================] - 9s 8ms/step - loss: 4.6148 - accuracy: 0.0103 - val_loss: 4.6328 - val_accuracy: 0.0093
# Epoch 24/50
# 1094/1094 [==============================] - 10s 9ms/step - loss: 4.6148 - accuracy: 0.0105 - val_loss: 4.6130 - val_accuracy: 0.0104

# %%
# Evaluamos el modelo
score = model.evaluate(X_test,y_test)
score

# %%
# Ploteamos la evolucion del loss durante el entrenamiento
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure
plt.plot(hist.history['loss'],label="loss")
plt.plot(hist.history['val_loss'],label="val_loss")
plt.legend()

# %%
# Ploteamos la evolucion del accuracy durante el entrenamiento
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure
plt.plot(hist.history['accuracy'],label="accuracy")
plt.plot(hist.history['val_accuracy'],label="val_accuracy")
plt.legend()

# %%
# Predecimos sobre test
preds_test = model.predict(X_test)
preds_test.shape

# %%
import numpy as np
# Elegimos una imagen de test
idx_mostrar = 2990
# Mostramos la imagen
plt.imshow(X_test[idx_mostrar,:,:,:])
# Mostramos las probabilidades que da el modelo a cada clase
print(np.argmax(preds_test[idx_mostrar]))
